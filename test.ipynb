# %%
import tensorflow as tf
import os
from tensorflow.keras.models import load_model
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
new_model = load_model('models\\imageclassifierlast.h5')

# %%
img = cv2.imread('test1.jpg')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
resize = tf.image.resize(img, (256,256))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
test=new_model.predict(np.expand_dims(resize/255, 0))

# %%
if test > 0.5: 
    print(f'Predicted class is Sad with {test}')
else:
    print(f'Predicted class is Happy with {test}')
# Out:
# Predicted class is Sad with [[0.9897905]]
